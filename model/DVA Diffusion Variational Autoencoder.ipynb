# %%
import gdown

# URL của thư mục Google Drive
url_urtil = 'https://drive.google.com/drive/folders/1zeuh98leocP3NOkPkaHf9bVaJabVQdZR?usp=drive_link'

# Chuyển đổi URL sang định dạng gdown
gdown.download_folder(url_urtil, quiet=False)

# URL của thư mục Google Drive
url_exp = 'https://drive.google.com/drive/folders/1K2XjH-G9K_YsnpmVnigXG4dJfuJPIxGW?usp=drive_link'

# Chuyển đổi URL sang định dạng gdown
gdown.download_folder(url_exp, quiet=False)

# URL của thư mục Google Drive
url_loader = 'https://drive.google.com/drive/folders/181BmR5Q-8dQZQOJXXDVliHanmlJRaVMb?usp=drive_link'

# Chuyển đổi URL sang định dạng gdown
gdown.download_folder(url_loader, quiet=False)

# URL của thư mục Google Drive
url_model = 'https://drive.google.com/drive/folders/1m4tziAkMeCCluoDA4s6p63Tipjg9qIC3?usp=drive_link'

# Chuyển đổi URL sang định dạng gdown
gdown.download_folder(url_model, quiet=False)
# Out:
# Retrieving folder contents
# Processing file 1_Py2s1b3BPABW1kedcnf12QX7Mqb9ei8 timefeatures.py
# Processing file 1oUo1hJVzVitiXpld0ichsfsWC6A3qQRm tools.py
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1_Py2s1b3BPABW1kedcnf12QX7Mqb9ei8
# From (redirected): https://drive.google.com/uc?id=1_Py2s1b3BPABW1kedcnf12QX7Mqb9ei8&confirm=t&uuid=1429f4d1-9eef-4b2b-b056-5b63f6d137fb
# To: /content/utils/timefeatures.py
# 100%|██████████| 3.81k/3.81k [00:00<00:00, 12.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1oUo1hJVzVitiXpld0ichsfsWC6A3qQRm
# From (redirected): https://drive.google.com/uc?id=1oUo1hJVzVitiXpld0ichsfsWC6A3qQRm&confirm=t&uuid=e90469e8-8836-48a4-b944-1ee1ab8603b2
# To: /content/utils/tools.py
# 100%|██████████| 1.85k/1.85k [00:00<00:00, 4.28MB/s]
# Download completed
# Retrieving folder contents
# Processing file 1i5DEHJAY5NHlBjt4MAELeyc4ECLulKs1 exp_model.py
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1i5DEHJAY5NHlBjt4MAELeyc4ECLulKs1
# From (redirected): https://drive.google.com/uc?id=1i5DEHJAY5NHlBjt4MAELeyc4ECLulKs1&confirm=t&uuid=d1786676-948d-4d26-86c2-3abd70585d2e
# To: /content/exp/exp_model.py
# 100%|██████████| 7.75k/7.75k [00:00<00:00, 22.2MB/s]
# Download completed
# Retrieving folder contents
# Processing file 1_KAYLohcArqU8FqeAsek9F6ItuGLfR8k data_loader.py
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1_KAYLohcArqU8FqeAsek9F6ItuGLfR8k
# From (redirected): https://drive.google.com/uc?id=1_KAYLohcArqU8FqeAsek9F6ItuGLfR8k&confirm=t&uuid=0fe1bf5b-c810-4b12-b1b5-d4462ed65825
# To: /content/data_load/data_loader.py
# 100%|██████████| 2.68k/2.68k [00:00<00:00, 9.90MB/s]
# Download completed
# Retrieving folder contents
# Processing file 1-uwZkFt4A5E-mv2G3siqdSg81WgnchP- diffusion_process.py
# Processing file 14fvijpcGbVQ9GPXnvMAQiTKDlJQHWxpD embedding.py
# Processing file 1CL6U2N5Za-C7qhFfraMViSoteD9w9Vl3 encoder.py
# Processing file 12iQ_ty1nvbbFTTf-VIVTPLKlpVwnSb61 model.py
# Processing file 1GXFz9Nq_xeFMX9fYwTvASaD9Xx_FPU-N neural_operations.py
# Processing file 199stZMhmKiV0nGIJW16hI5kMF3OBKapS resnet.py
# Processing file 1bRfnW8dhum7BsiPa6vl-wkpBdbAX6kyn utils.py
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1-uwZkFt4A5E-mv2G3siqdSg81WgnchP-
# From (redirected): https://drive.google.com/uc?id=1-uwZkFt4A5E-mv2G3siqdSg81WgnchP-&confirm=t&uuid=d94cdd48-d9b1-46a5-83db-cdf16593f9f8
# To: /content/model/diffusion_process.py
# 100%|██████████| 4.62k/4.62k [00:00<00:00, 13.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=14fvijpcGbVQ9GPXnvMAQiTKDlJQHWxpD
# From (redirected): https://drive.google.com/uc?id=14fvijpcGbVQ9GPXnvMAQiTKDlJQHWxpD&confirm=t&uuid=26b1fe4c-eb23-4508-95b0-873c0006dc5d
# To: /content/model/embedding.py
# 100%|██████████| 3.04k/3.04k [00:00<00:00, 10.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1CL6U2N5Za-C7qhFfraMViSoteD9w9Vl3
# From (redirected): https://drive.google.com/uc?id=1CL6U2N5Za-C7qhFfraMViSoteD9w9Vl3&confirm=t&uuid=429964c9-22a8-4d06-9258-63221820ff75
# To: /content/model/encoder.py
# 100%|██████████| 11.7k/11.7k [00:00<00:00, 32.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=12iQ_ty1nvbbFTTf-VIVTPLKlpVwnSb61
# From (redirected): https://drive.google.com/uc?id=12iQ_ty1nvbbFTTf-VIVTPLKlpVwnSb61&confirm=t&uuid=0671cca0-cbff-4738-baf9-27c4eb2f31bb
# To: /content/model/model.py
# 100%|██████████| 5.36k/5.36k [00:00<00:00, 16.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1GXFz9Nq_xeFMX9fYwTvASaD9Xx_FPU-N
# From (redirected): https://drive.google.com/uc?id=1GXFz9Nq_xeFMX9fYwTvASaD9Xx_FPU-N&confirm=t&uuid=6e5be39a-3a9c-4e31-b32c-270a14ee5039
# To: /content/model/neural_operations.py
# 100%|██████████| 10.5k/10.5k [00:00<00:00, 27.3MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=199stZMhmKiV0nGIJW16hI5kMF3OBKapS
# From (redirected): https://drive.google.com/uc?id=199stZMhmKiV0nGIJW16hI5kMF3OBKapS&confirm=t&uuid=fb6dd3e6-0db7-4e54-b158-bb131c141c29
# To: /content/model/resnet.py
# 100%|██████████| 5.44k/5.44k [00:00<00:00, 15.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1bRfnW8dhum7BsiPa6vl-wkpBdbAX6kyn
# From (redirected): https://drive.google.com/uc?id=1bRfnW8dhum7BsiPa6vl-wkpBdbAX6kyn&confirm=t&uuid=dbf2e7ee-badf-490b-ae54-c1dcc05c8b42
# To: /content/model/utils.py
# 100%|██████████| 8.04k/8.04k [00:00<00:00, 21.3MB/s]
# Download completed
# ['/content/model/diffusion_process.py',
#  '/content/model/embedding.py',
#  '/content/model/encoder.py',
#  '/content/model/model.py',
#  '/content/model/neural_operations.py',
#  '/content/model/resnet.py',
#  '/content/model/utils.py']

# %%
# Cài đặt gluonts phiên bản 0.11.7
# !pip install gluonts
# Out:
# Collecting gluonts
#   Downloading gluonts-0.15.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy~=1.16 in /usr/local/lib/python3.10/dist-packages (from gluonts) (1.25.2)
# Requirement already satisfied: pandas<3,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gluonts) (2.0.3)
# Requirement already satisfied: pydantic<3,>=1.7 in /usr/local/lib/python3.10/dist-packages (from gluonts) (2.8.2)
# Requirement already satisfied: tqdm~=4.23 in /usr/local/lib/python3.10/dist-packages (from gluonts) (4.66.4)
# Requirement already satisfied: toolz~=0.10 in /usr/local/lib/python3.10/dist-packages (from gluonts) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gluonts) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.0->gluonts) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.0->gluonts) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.0->gluonts) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.7->gluonts) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.7->gluonts) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.0->gluonts) (1.16.0)
# Downloading gluonts-0.15.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.2 MB/s eta 0:00:00
# Installing collected packages: gluonts
# Successfully installed gluonts-0.15.1

# %%
# !pip install lightning
# Out:
# Collecting lightning
#   Downloading lightning-2.3.3-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.6.1)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning)
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from lightning) (1.25.2)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (24.1)
# Requirement already satisfied: torch<4.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (2.3.1+cu121)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning)
#   Downloading torchmetrics-1.4.0.post0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (4.66.4)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (4.12.2)
# Collecting pytorch-lightning (from lightning)
#   Downloading pytorch_lightning-2.3.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (71.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.0.0->lightning) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.0.0->lightning) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.0.0->lightning) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.0.0->lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<4.0,>=2.0.0->lightning)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.0.0->lightning) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch<4.0,>=2.0.0->lightning)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<4.0,>=2.0.0->lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<4.0,>=2.0.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.7)
# Downloading lightning-2.3.3-py3-none-any.whl (808 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.5/808.5 kB 50.1 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 1.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.3.3-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 46.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 49.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, pytorch-lightning, lightning
# Successfully installed lightning-2.3.3 lightning-utilities-0.11.6 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 pytorch-lightning-2.3.3 torchmetrics-1.4.0.post0

# %% [markdown]
# # Hàm main

# %%
# # -*-Encoding: utf-8 -*-
# import argparse
# import torch
# import numpy as np
# import random
# from exp.exp_model import Exp_Model
# import os
# import pandas as pd
# #drive/MyDrive/dva-main
# fix_seed = 100
# random.seed(fix_seed)
# torch.manual_seed(fix_seed)
# np.random.seed(fix_seed)

# parser = argparse.ArgumentParser(description='generating')
# print(1)
# # Load data
# parser.add_argument('--root_path', type=str, default='./data/2016', help='root path of the data files')
# print(2)
# parser.add_argument('--checkpoints', type=str, default='./checkpoints/', help='location of model checkpoints')
# parser.add_argument('--sequence_length', type=int, default=10, help='length of input sequence')
# parser.add_argument('--prediction_length', type=int, default=None, help='prediction sequence length')
# parser.add_argument('--target_dim', type=int, default=1, help='dimension of target')
# parser.add_argument('--input_dim', type=int, default=6, help='dimension of input')
# parser.add_argument('--hidden_size', type=int, default=128, help='encoder dimension')
# parser.add_argument('--embedding_dimension', type=int, default=64, help='feature embedding dimension')
# print(3)
# # Diffusion process
# parser.add_argument('--diff_steps', type=int, default=1000, help='number of the diff step')
# parser.add_argument('--dropout_rate', type=float, default=0.1, help='dropout')
# parser.add_argument('--beta_schedule', type=str, default='linear', help='the schedule of beta')
# parser.add_argument('--beta_start', type=float, default=0.0, help='start of the beta')
# parser.add_argument('--beta_end', type=float, default=1.0, help='end of the beta')
# parser.add_argument('--scale', type=float, default=0.1, help='adjust diffusion scale')
# print(4)
# # Bidirectional VAE
# parser.add_argument('--arch_instance', type=str, default='res_mbconv', help='path to the architecture instance')
# parser.add_argument('--mult', type=float, default=1, help='mult of channels')
# parser.add_argument('--num_layers', type=int, default=2, help='num of RNN layers')
# parser.add_argument('--num_channels_enc', type=int, default=32, help='number of channels in encoder')
# parser.add_argument('--channel_mult', type=int, default=2, help='number of channels in encoder')
# parser.add_argument('--num_preprocess_blocks', type=int, default=1, help='number of preprocessing blocks')
# parser.add_argument('--num_preprocess_cells', type=int, default=3, help='number of cells per block')
# parser.add_argument('--groups_per_scale', type=int, default=2, help='number of cells per block')
# parser.add_argument('--num_postprocess_blocks', type=int, default=1, help='number of postprocessing blocks')
# parser.add_argument('--num_postprocess_cells', type=int, default=2, help='number of cells per block')
# parser.add_argument('--num_channels_dec', type=int, default=32, help='number of channels in decoder')
# parser.add_argument('--num_latent_per_group', type=int, default=8, help='number of channels in latent variables per group')
# print(5)
# # Training settings
# parser.add_argument('--num_workers', type=int, default=5, help='data loader num workers')
# parser.add_argument('--patience', type=int, default=3, help='early stopping patience')
# parser.add_argument('--itr', type=int, default=5, help='experiment times')
# parser.add_argument('--train_epochs', type=int, default=20, help='train epochs')
# parser.add_argument('--batch_size', type=int, default=16, help='batch size of train input data')
# parser.add_argument('--learning_rate', type=float, default=0.0005, help='optimizer learning rate')
# parser.add_argument('--weight_decay', type=float, default=0.0000, help='weight decay')
# parser.add_argument('--zeta', type=float, default=0.5, help='trade off parameter zeta')
# parser.add_argument('--eta', type=float, default=1.0, help='trade off parameter eta')
# print(6)
# # Device
# parser.add_argument('--use_gpu', type=bool, default=True, help='use gpu')
# parser.add_argument('--gpu', type=int, default=0, help='gpu')
# print(7)
# args = parser.parse_args()
# print(71)
# args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False
# print(8)
# if args.prediction_length is None:
#     args.prediction_length = args.sequence_length
# print(9)
# print('Args in experiment:')
# print(args)

# Exp = Exp_Model
# results = pd.DataFrame(columns=['Ticker', 'MSE', 'StdDev'])
# train_setting = 'tp{}_sl{}'.format(args.root_path.split(os.sep)[-1], args.sequence_length)

# for idx, file in enumerate(os.listdir(args.root_path)): # Iterate through all tickers
#     print('\n\nRunning on file {} ({}/{})...'.format(file, idx+1, len(os.listdir(args.root_path))))
#     args.data_path = file
#     ticker = os.path.splitext(file)[0]
#     all_mse = []

#     for ii in range(0, args.itr):
#         setting = args.data_path + '_' + train_setting
#         exp = Exp(args)  # single experiment
#         print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
#         exp.train(setting)
#         print('>>>>>>>start testing : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
#         mse = exp.test(setting)
#         all_mse.append(mse)
#         torch.cuda.empty_cache()

#     results = results.append({'Ticker': ticker, 'MSE': np.mean(np.array(all_mse)), 'StdDev': np.std(np.array(all_mse))}, ignore_index=True)

# folder_path = './results/'
# if not os.path.exists(folder_path):
#     os.makedirs(folder_path)
# results.to_csv(folder_path + train_setting + '.csv', index=False)
# print(results)

# %%
import argparse
import sys
import torch
import numpy as np
import random
from exp.exp_model import Exp_Model
import os
import pandas as pd

def get_args():
    parser = argparse.ArgumentParser(description='generating')

    # Load data
    parser.add_argument('--root_path', type=str, default='drive/MyDrive/dva-main/data/2016', help='root path of the data files')
    parser.add_argument('--checkpoints', type=str, default='./checkpoints/', help='location of model checkpoints')
    parser.add_argument('--sequence_length', type=int, default=10, help='length of input sequence')
    parser.add_argument('--prediction_length', type=int, default=None, help='prediction sequence length')
    parser.add_argument('--target_dim', type=int, default=1, help='dimension of target')
    parser.add_argument('--input_dim', type=int, default=6, help='dimension of input')
    parser.add_argument('--hidden_size', type=int, default=128, help='encoder dimension')
    parser.add_argument('--embedding_dimension', type=int, default=64, help='feature embedding dimension')

    # Diffusion process
    parser.add_argument('--diff_steps', type=int, default=1000, help='number of the diff step')
    parser.add_argument('--dropout_rate', type=float, default=0.1, help='dropout')
    parser.add_argument('--beta_schedule', type=str, default='linear', help='the schedule of beta')
    parser.add_argument('--beta_start', type=float, default=0.0, help='start of the beta')
    parser.add_argument('--beta_end', type=float, default=1.0, help='end of the beta')
    parser.add_argument('--scale', type=float, default=0.1, help='adjust diffusion scale')

    # Bidirectional VAE
    parser.add_argument('--arch_instance', type=str, default='res_mbconv', help='path to the architecture instance')
    parser.add_argument('--mult', type=float, default=1, help='mult of channels')
    parser.add_argument('--num_layers', type=int, default=2, help='num of RNN layers')
    parser.add_argument('--num_channels_enc', type=int, default=32, help='number of channels in encoder')
    parser.add_argument('--channel_mult', type=int, default=2, help='number of channels in encoder')
    parser.add_argument('--num_preprocess_blocks', type=int, default=1, help='number of preprocessing blocks')
    parser.add_argument('--num_preprocess_cells', type=int, default=3, help='number of cells per block')
    parser.add_argument('--groups_per_scale', type=int, default=2, help='number of cells per block')
    parser.add_argument('--num_postprocess_blocks', type=int, default=1, help='number of postprocessing blocks')
    parser.add_argument('--num_postprocess_cells', type=int, default=2, help='number of cells per block')
    parser.add_argument('--num_channels_dec', type=int, default=32, help='number of channels in decoder')
    parser.add_argument('--num_latent_per_group', type=int, default=8, help='number of channels in latent variables per group')

    # Training settings
    parser.add_argument('--num_workers', type=int, default=5, help='data loader num workers')
    parser.add_argument('--patience', type=int, default=3, help='early stopping patience')
    parser.add_argument('--itr', type=int, default=5, help='experiment times')
    parser.add_argument('--train_epochs', type=int, default=20, help='train epochs')
    parser.add_argument('--batch_size', type=int, default=16, help='batch size of train input data')
    parser.add_argument('--learning_rate', type=float, default=0.0005, help='optimizer learning rate')
    parser.add_argument('--weight_decay', type=float, default=0.0000, help='weight decay')
    parser.add_argument('--zeta', type=float, default=0.5, help='trade off parameter zeta')
    parser.add_argument('--eta', type=float, default=1.0, help='trade off parameter eta')

    # Device
    parser.add_argument('--use_gpu', type=bool, default=True, help='use gpu')
    parser.add_argument('--gpu', type=int, default=0, help='gpu')

    # Lọc bỏ các đối số không mong muốn
    args, unknown = parser.parse_known_args()
    print(unknown)
    return args

args = get_args()

args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.prediction_length is None:
    args.prediction_length = args.sequence_length

print('Args in experiment:')
print(args)
# Out:
# ['-f', '/root/.local/share/jupyter/runtime/kernel-f5e3a4b0-173d-4b9e-8495-d5d731fc9308.json']
# Args in experiment:
# Namespace(root_path='drive/MyDrive/dva-main/data/2016', checkpoints='./checkpoints/', sequence_length=10, prediction_length=10, target_dim=1, input_dim=6, hidden_size=128, embedding_dimension=64, diff_steps=1000, dropout_rate=0.1, beta_schedule='linear', beta_start=0.0, beta_end=1.0, scale=0.1, arch_instance='res_mbconv', mult=1, num_layers=2, num_channels_enc=32, channel_mult=2, num_preprocess_blocks=1, num_preprocess_cells=3, groups_per_scale=2, num_postprocess_blocks=1, num_postprocess_cells=2, num_channels_dec=32, num_latent_per_group=8, num_workers=5, patience=3, itr=5, train_epochs=20, batch_size=16, learning_rate=0.0005, weight_decay=0.0, zeta=0.5, eta=1.0, use_gpu=True, gpu=0)

# %%
Exp = Exp_Model
results = pd.DataFrame(columns=['Ticker', 'MSE', 'StdDev'])
train_setting = 'tp{}_sl{}'.format(args.root_path.split(os.sep)[-1], args.sequence_length)

for idx, file in enumerate(os.listdir(args.root_path)): # Iterate through all tickers
    print('\n\nRunning on file {} ({}/{})...'.format(file, idx+1, len(os.listdir(args.root_path))))
    args.data_path = file
    ticker = os.path.splitext(file)[0]
    all_mse = []

    for ii in range(0, args.itr):
        setting = args.data_path + '_' + train_setting
        exp = Exp(args)  # single experiment
        print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
        exp.train(setting)
        print('>>>>>>>start testing : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
        mse = exp.test(setting)
        all_mse.append(mse)
        torch.cuda.empty_cache()

    new_row = pd.DataFrame({'Ticker': [ticker], 'MSE': [np.mean(np.array(all_mse))], 'StdDev': [np.std(np.array(all_mse))]})
    results = pd.concat([results, new_row], ignore_index=True)

folder_path = './results/'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
results.to_csv(folder_path + train_setting + '.csv', index=False)
print(results)
# Out:
# Running on file SRE.csv (1/85)...
# Use GPU: cuda:0
# >>>>>>>start training : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(27.3546, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9389986 KL Loss: 7.3856671 DSM Loss: 14.5682654 Overall Loss:23.8929310
# Validation loss decreased (inf --> 0.749214).  Saving model ...
# Updating learning rate to 0.0005
# tensor(21.5951, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8514463 KL Loss: 7.2301127 DSM Loss: 11.1430140 Overall Loss:20.2245730
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(16.4486, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8854670 KL Loss: 7.1842819 DSM Loss: 10.0958369 Overall Loss:19.1655859
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# tensor(18.8519, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7971960 KL Loss: 7.2099974 DSM Loss: 9.9033981 Overall Loss:18.9105915
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.2987439632415771
# Use GPU: cuda:0
# >>>>>>>start training : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(24.0733, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7461701 KL Loss: 7.1970776 DSM Loss: 14.5113009 Overall Loss:23.4545485
# Validation loss decreased (inf --> 0.770833).  Saving model ...
# Updating learning rate to 0.0005
# tensor(24.2559, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7699075 KL Loss: 7.1648243 DSM Loss: 11.6892343 Overall Loss:20.6239661
# Validation loss decreased (0.770833 --> 0.752949).  Saving model ...
# Updating learning rate to 0.00025
# tensor(25.1197, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8928359 KL Loss: 7.3603896 DSM Loss: 10.9727070 Overall Loss:20.2259325
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(23.1782, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8365355 KL Loss: 7.2022025 DSM Loss: 10.5205416 Overall Loss:19.5592793
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# tensor(17.2918, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8170513 KL Loss: 7.1924025 DSM Loss: 10.4624533 Overall Loss:19.4719073
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.2799742221832275
# Use GPU: cuda:0
# >>>>>>>start training : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.1079, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7603279 KL Loss: 7.2337086 DSM Loss: 13.2165872 Overall Loss:22.2106238
# Validation loss decreased (inf --> 0.753982).  Saving model ...
# Updating learning rate to 0.0005
# tensor(21.8163, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8796326 KL Loss: 7.2078008 DSM Loss: 10.4640712 Overall Loss:19.5515046
# Validation loss decreased (0.753982 --> 0.745923).  Saving model ...
# Updating learning rate to 0.00025
# tensor(21.7444, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8428141 KL Loss: 7.2003408 DSM Loss: 9.8331078 Overall Loss:18.8762628
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(17.2035, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7839798 KL Loss: 7.1627796 DSM Loss: 9.9001892 Overall Loss:18.8469484
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# tensor(18.2338, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8110034 KL Loss: 7.1403810 DSM Loss: 9.5865389 Overall Loss:18.5379234
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.277050256729126
# Use GPU: cuda:0
# >>>>>>>start training : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(25.0682, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8382054 KL Loss: 7.2567772 DSM Loss: 13.9824158 Overall Loss:23.0773985
# Validation loss decreased (inf --> 0.801635).  Saving model ...
# Updating learning rate to 0.0005
# tensor(25.1742, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8532915 KL Loss: 7.2393807 DSM Loss: 11.3284306 Overall Loss:20.4211028
# Validation loss decreased (0.801635 --> 0.771530).  Saving model ...
# Updating learning rate to 0.00025
# tensor(19.8514, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7592447 KL Loss: 7.0934566 DSM Loss: 10.0073968 Overall Loss:18.8600980
# Validation loss decreased (0.771530 --> 0.762736).  Saving model ...
# Updating learning rate to 0.000125
# tensor(17.8638, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7795544 KL Loss: 7.1204882 DSM Loss: 9.8424806 Overall Loss:18.7425233
# Validation loss decreased (0.762736 --> 0.756148).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(16.4995, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7483245 KL Loss: 7.3202960 DSM Loss: 9.9010961 Overall Loss:18.9697167
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(18.8052, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8268516 KL Loss: 7.1390828 DSM Loss: 9.9235489 Overall Loss:18.8894831
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(19.9790, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8290428 KL Loss: 7.2985422 DSM Loss: 9.4632259 Overall Loss:18.5908108
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.268435001373291
# Use GPU: cuda:0
# >>>>>>>start training : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(29.7403, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9576298 KL Loss: 7.4115497 DSM Loss: 14.6870079 Overall Loss:24.0561874
# Validation loss decreased (inf --> 0.768591).  Saving model ...
# Updating learning rate to 0.0005
# tensor(18.5966, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.9130578 KL Loss: 7.3183457 DSM Loss: 10.2654752 Overall Loss:19.4968787
# Validation loss decreased (0.768591 --> 0.754417).  Saving model ...
# Updating learning rate to 0.00025
# tensor(18.2756, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8071186 KL Loss: 7.2303212 DSM Loss: 10.0711219 Overall Loss:19.1085615
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(19.3353, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8044133 KL Loss: 7.2709669 DSM Loss: 9.8351431 Overall Loss:18.9105233
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# tensor(17.2106, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7669092 KL Loss: 7.0616966 DSM Loss: 9.7281285 Overall Loss:18.5567344
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : SRE.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.2666782140731812
#
#
# Running on file BHP.csv (2/85)...
# Use GPU: cuda:0
# >>>>>>>start training : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(28.7052, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8738420 KL Loss: 7.2173943 DSM Loss: 13.8680798 Overall Loss:22.9593161
# Validation loss decreased (inf --> 3.004428).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.0926, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8495154 KL Loss: 7.2566946 DSM Loss: 10.0006113 Overall Loss:19.1068212
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(22.5154, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7574367 KL Loss: 7.1404191 DSM Loss: 10.1444850 Overall Loss:19.0423406
# Validation loss decreased (3.004428 --> 2.989118).  Saving model ...
# Updating learning rate to 0.000125
# tensor(20.4000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7944270 KL Loss: 7.2586325 DSM Loss: 9.5689033 Overall Loss:18.6219627
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(19.1579, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7183330 KL Loss: 7.1096198 DSM Loss: 9.6989059 Overall Loss:18.5268587
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(18.7269, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7683650 KL Loss: 7.1230212 DSM Loss: 9.5479532 Overall Loss:18.4393397
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.254428505897522
# Use GPU: cuda:0
# >>>>>>>start training : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.3470, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8417598 KL Loss: 7.1474996 DSM Loss: 14.5812725 Overall Loss:23.5705320
# Validation loss decreased (inf --> 3.039256).  Saving model ...
# Updating learning rate to 0.0005
# tensor(21.2977, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7243402 KL Loss: 7.2211729 DSM Loss: 11.1112625 Overall Loss:20.0567757
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(15.8633, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8359192 KL Loss: 7.1645229 DSM Loss: 9.3867474 Overall Loss:18.3871892
# Validation loss decreased (3.039256 --> 3.017216).  Saving model ...
# Updating learning rate to 0.000125
# tensor(22.3271, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7565724 KL Loss: 7.1586771 DSM Loss: 9.5403195 Overall Loss:18.4555689
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(21.9169, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8036965 KL Loss: 7.2252868 DSM Loss: 9.5287339 Overall Loss:18.5577170
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(25.8151, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8378385 KL Loss: 7.2647359 DSM Loss: 9.2811370 Overall Loss:18.3837114
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.276471495628357
# Use GPU: cuda:0
# >>>>>>>start training : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(25.6919, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8237151 KL Loss: 7.2657225 DSM Loss: 13.6387096 Overall Loss:22.7281469
# Validation loss decreased (inf --> 3.101007).  Saving model ...
# Updating learning rate to 0.0005
# tensor(26.1345, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8848462 KL Loss: 7.2902656 DSM Loss: 10.4711163 Overall Loss:19.6462282
# Validation loss decreased (3.101007 --> 3.002269).  Saving model ...
# Updating learning rate to 0.00025
# tensor(19.9201, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8271972 KL Loss: 7.2156508 DSM Loss: 9.7966559 Overall Loss:18.8395037
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(19.2299, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7435483 KL Loss: 7.1815417 DSM Loss: 9.7817335 Overall Loss:18.7068236
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# tensor(17.1623, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8142279 KL Loss: 7.2908248 DSM Loss: 9.5073842 Overall Loss:18.6124368
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.2583647966384888
# Use GPU: cuda:0
# >>>>>>>start training : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(30.1845, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7949002 KL Loss: 7.2015360 DSM Loss: 13.9346213 Overall Loss:22.9310575
# Validation loss decreased (inf --> 3.083465).  Saving model ...
# Updating learning rate to 0.0005
# tensor(25.2820, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8147282 KL Loss: 7.2327337 DSM Loss: 9.9157000 Overall Loss:18.9631619
# Validation loss decreased (3.083465 --> 3.080037).  Saving model ...
# Updating learning rate to 0.00025
# tensor(21.0555, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7250426 KL Loss: 7.0485081 DSM Loss: 9.9084575 Overall Loss:18.6820085
# Validation loss decreased (3.080037 --> 3.014533).  Saving model ...
# Updating learning rate to 0.000125
# tensor(23.2644, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7589076 KL Loss: 7.1613408 DSM Loss: 9.8933883 Overall Loss:18.8136365
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(20.0588, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7866820 KL Loss: 7.2198491 DSM Loss: 9.5249238 Overall Loss:18.5314548
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(15.4441, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7523412 KL Loss: 7.2537649 DSM Loss: 9.2303286 Overall Loss:18.2364347
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.2716630697250366
# Use GPU: cuda:0
# >>>>>>>start training : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(27.4983, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8395932 KL Loss: 7.2478318 DSM Loss: 13.3584661 Overall Loss:22.4458913
# Validation loss decreased (inf --> 3.001618).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.8843, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8332882 KL Loss: 7.2544708 DSM Loss: 10.2429000 Overall Loss:19.3306591
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(19.5086, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8586651 KL Loss: 7.2715653 DSM Loss: 9.8113272 Overall Loss:18.9415576
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# tensor(23.3406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8088307 KL Loss: 7.2138656 DSM Loss: 9.6453942 Overall Loss:18.6680904
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : BHP.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.2716407775878906
#
#
# Running on file UTX.csv (3/85)...
# Use GPU: cuda:0
# >>>>>>>start training : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(32.1134, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9275579 KL Loss: 7.3446566 DSM Loss: 14.1767877 Overall Loss:23.4490022
# Validation loss decreased (inf --> 1.210312).  Saving model ...
# Updating learning rate to 0.0005
# tensor(22.2110, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8329969 KL Loss: 7.2611955 DSM Loss: 11.1738475 Overall Loss:20.2680400
# Validation loss decreased (1.210312 --> 1.181385).  Saving model ...
# Updating learning rate to 0.00025
# tensor(18.1638, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8682202 KL Loss: 7.2662809 DSM Loss: 10.1133924 Overall Loss:19.2478932
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(20.3178, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7819205 KL Loss: 7.2389998 DSM Loss: 9.5597786 Overall Loss:18.5806988
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# tensor(15.9829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7839269 KL Loss: 7.2193609 DSM Loss: 9.7539879 Overall Loss:18.7572756
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7602728605270386
# Use GPU: cuda:0
# >>>>>>>start training : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.1439, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9150673 KL Loss: 7.1762830 DSM Loss: 16.3370740 Overall Loss:25.4284242
# Validation loss decreased (inf --> 1.187238).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.0220, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8744539 KL Loss: 7.3353420 DSM Loss: 10.7057008 Overall Loss:19.9154967
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(20.1841, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8975008 KL Loss: 7.2141087 DSM Loss: 10.0636372 Overall Loss:19.1752467
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# tensor(16.9393, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8525975 KL Loss: 7.2255933 DSM Loss: 9.7892736 Overall Loss:18.8674644
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7594383358955383
# Use GPU: cuda:0
# >>>>>>>start training : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(28.4325, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8876759 KL Loss: 7.3188122 DSM Loss: 14.8870608 Overall Loss:24.0935489
# Validation loss decreased (inf --> 1.150944).  Saving model ...
# Updating learning rate to 0.0005
# tensor(22.3061, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8282701 KL Loss: 7.3107496 DSM Loss: 10.4237109 Overall Loss:19.5627305
# Validation loss decreased (1.150944 --> 1.140973).  Saving model ...
# Updating learning rate to 0.00025
# tensor(17.9388, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.9096326 KL Loss: 7.2010233 DSM Loss: 10.0583318 Overall Loss:19.1689877
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(19.3969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8218386 KL Loss: 7.1149056 DSM Loss: 9.7740226 Overall Loss:18.7107668
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# tensor(17.5034, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7631438 KL Loss: 7.1372739 DSM Loss: 9.7527129 Overall Loss:18.6531306
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7528933882713318
# Use GPU: cuda:0
# >>>>>>>start training : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(30.4148, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8376257 KL Loss: 7.2386029 DSM Loss: 13.3475646 Overall Loss:22.4237931
# Validation loss decreased (inf --> 1.243780).  Saving model ...
# Updating learning rate to 0.0005
# tensor(22.5035, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8123436 KL Loss: 7.2471099 DSM Loss: 10.7420561 Overall Loss:19.8015095
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(18.2562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.6982109 KL Loss: 7.0748661 DSM Loss: 10.0058019 Overall Loss:18.7788788
# Validation loss decreased (1.243780 --> 1.208300).  Saving model ...
# Updating learning rate to 0.000125
# tensor(18.1244, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8051008 KL Loss: 7.2205025 DSM Loss: 9.7009413 Overall Loss:18.7265447
# Validation loss decreased (1.208300 --> 1.195076).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(14.9155, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7650730 KL Loss: 7.1610572 DSM Loss: 9.6929791 Overall Loss:18.6191094
# Validation loss decreased (1.195076 --> 1.173197).  Saving model ...
# Updating learning rate to 3.125e-05
# tensor(17.4018, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7729192 KL Loss: 7.0901341 DSM Loss: 9.7794961 Overall Loss:18.6425494
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-05
# tensor(19.2806, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7953584 KL Loss: 7.2698106 DSM Loss: 9.6487940 Overall Loss:18.7139629
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-06
# tensor(20.1287, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 8, Steps: 31 | MSE Loss: 1.7761909 KL Loss: 7.2669130 DSM Loss: 9.5446363 Overall Loss:18.5877403
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7559839487075806
# Use GPU: cuda:0
# >>>>>>>start training : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(27.9930, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8950192 KL Loss: 7.3472667 DSM Loss: 14.8941605 Overall Loss:24.1364462
# Validation loss decreased (inf --> 1.199479).  Saving model ...
# Updating learning rate to 0.0005
# tensor(17.0094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7378069 KL Loss: 7.1649207 DSM Loss: 11.2385262 Overall Loss:20.1412539
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(20.1911, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8520554 KL Loss: 7.2181930 DSM Loss: 10.4940311 Overall Loss:19.5642794
# Validation loss decreased (1.199479 --> 1.149500).  Saving model ...
# Updating learning rate to 0.000125
# tensor(18.3088, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8128550 KL Loss: 7.1791274 DSM Loss: 9.8160828 Overall Loss:18.8080651
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(21.1020, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8132690 KL Loss: 7.1599252 DSM Loss: 9.7051845 Overall Loss:18.6783789
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(19.7469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7828604 KL Loss: 7.2301321 DSM Loss: 9.5421748 Overall Loss:18.5551672
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UTX.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7541695833206177
#
#
# Running on file XOM.csv (4/85)...
# Use GPU: cuda:0
# >>>>>>>start training : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(24.9498, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8616889 KL Loss: 7.2363836 DSM Loss: 14.3089296 Overall Loss:23.4070020
# Validation loss decreased (inf --> 0.484513).  Saving model ...
# Updating learning rate to 0.0005
# tensor(17.4938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8026413 KL Loss: 7.2104964 DSM Loss: 10.8703509 Overall Loss:19.8834886
# Validation loss decreased (0.484513 --> 0.468118).  Saving model ...
# Updating learning rate to 0.00025
# tensor(13.6134, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8307480 KL Loss: 7.1238297 DSM Loss: 10.1140261 Overall Loss:19.0686040
# Validation loss decreased (0.468118 --> 0.449993).  Saving model ...
# Updating learning rate to 0.000125
# tensor(24.5116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8075838 KL Loss: 7.1808254 DSM Loss: 9.5222814 Overall Loss:18.5106905
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(17.7238, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7615003 KL Loss: 7.0939034 DSM Loss: 9.6296127 Overall Loss:18.4850165
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(15.3236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7281684 KL Loss: 7.1967982 DSM Loss: 9.3637278 Overall Loss:18.2886942
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.6440625190734863
# Use GPU: cuda:0
# >>>>>>>start training : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(24.6738, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8389031 KL Loss: 7.3355519 DSM Loss: 13.7388742 Overall Loss:22.9133292
# Validation loss decreased (inf --> 0.464232).  Saving model ...
# Updating learning rate to 0.0005
# tensor(16.9700, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8200416 KL Loss: 7.1610277 DSM Loss: 10.7554886 Overall Loss:19.7365579
# Validation loss decreased (0.464232 --> 0.441867).  Saving model ...
# Updating learning rate to 0.00025
# tensor(17.4916, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8861299 KL Loss: 7.2287936 DSM Loss: 9.7051649 Overall Loss:18.8200883
# Validation loss decreased (0.441867 --> 0.441757).  Saving model ...
# Updating learning rate to 0.000125
# tensor(14.7834, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8259986 KL Loss: 7.2016621 DSM Loss: 9.6354402 Overall Loss:18.6631010
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(19.6047, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7780043 KL Loss: 7.1151908 DSM Loss: 9.5782941 Overall Loss:18.4714890
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(17.0847, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7693386 KL Loss: 7.1660095 DSM Loss: 9.6024816 Overall Loss:18.5378296
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.6443808674812317
# Use GPU: cuda:0
# >>>>>>>start training : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(29.8651, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8398540 KL Loss: 7.2789806 DSM Loss: 14.2807333 Overall Loss:23.3995678
# Validation loss decreased (inf --> 0.513792).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.6320, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8494995 KL Loss: 7.1240513 DSM Loss: 10.6756044 Overall Loss:19.6491552
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(20.9471, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8210070 KL Loss: 7.2214282 DSM Loss: 10.0954870 Overall Loss:19.1379222
# Validation loss decreased (0.513792 --> 0.471895).  Saving model ...
# Updating learning rate to 0.000125
# tensor(17.0386, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8108435 KL Loss: 7.2877125 DSM Loss: 9.5907113 Overall Loss:18.6892674
# Validation loss decreased (0.471895 --> 0.449397).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(17.2067, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8444225 KL Loss: 7.1667007 DSM Loss: 9.6230400 Overall Loss:18.6341631
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(18.6516, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7825465 KL Loss: 7.2689783 DSM Loss: 9.0658014 Overall Loss:18.1173259
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(18.3447, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7526366 KL Loss: 7.2143843 DSM Loss: 9.3595393 Overall Loss:18.3265602
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.6394020318984985
# Use GPU: cuda:0
# >>>>>>>start training : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(25.5909, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8251292 KL Loss: 7.2247891 DSM Loss: 13.9592356 Overall Loss:23.0091539
# Validation loss decreased (inf --> 0.497907).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.7416, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8084518 KL Loss: 7.2047826 DSM Loss: 10.7925429 Overall Loss:19.8057773
# Validation loss decreased (0.497907 --> 0.486441).  Saving model ...
# Updating learning rate to 0.00025
# tensor(20.4253, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7262195 KL Loss: 7.0864765 DSM Loss: 10.1863002 Overall Loss:18.9989962
# Validation loss decreased (0.486441 --> 0.469266).  Saving model ...
# Updating learning rate to 0.000125
# tensor(15.7760, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8528557 KL Loss: 7.1655108 DSM Loss: 9.5958629 Overall Loss:18.6142294
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(24.6774, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8332717 KL Loss: 7.3002747 DSM Loss: 9.6180024 Overall Loss:18.7515486
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(17.1288, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7933487 KL Loss: 7.1926559 DSM Loss: 9.6187985 Overall Loss:18.6048031
# Validation loss decreased (0.469266 --> 0.459901).  Saving model ...
# Updating learning rate to 1.5625e-05
# tensor(22.0737, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7715997 KL Loss: 7.1738900 DSM Loss: 9.4308263 Overall Loss:18.3763161
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-06
# tensor(15.5769, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 8, Steps: 31 | MSE Loss: 1.7654199 KL Loss: 7.1216623 DSM Loss: 9.4277552 Overall Loss:18.3148375
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-06
# tensor(16.2037, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 9, Steps: 31 | MSE Loss: 1.7421688 KL Loss: 7.0989132 DSM Loss: 9.4827292 Overall Loss:18.3238111
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.639022946357727
# Use GPU: cuda:0
# >>>>>>>start training : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.2707, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7616068 KL Loss: 7.1719151 DSM Loss: 14.7859101 Overall Loss:23.7194322
# Validation loss decreased (inf --> 0.444679).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.1251, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7215422 KL Loss: 7.1362483 DSM Loss: 11.0517681 Overall Loss:19.9095586
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(24.8266, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7387020 KL Loss: 7.0279481 DSM Loss: 10.0323675 Overall Loss:18.7990175
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# tensor(26.0961, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7346869 KL Loss: 7.2412097 DSM Loss: 9.5416340 Overall Loss:18.5175305
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : XOM.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.6429986357688904
#
#
# Running on file MCD.csv (5/85)...
# Use GPU: cuda:0
# >>>>>>>start training : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.1097, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8387967 KL Loss: 7.3026208 DSM Loss: 12.4815722 Overall Loss:21.6229896
# Validation loss decreased (inf --> 0.581748).  Saving model ...
# Updating learning rate to 0.0005
# tensor(18.3105, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7498929 KL Loss: 7.1611189 DSM Loss: 10.1546498 Overall Loss:19.0656615
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(23.5204, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8169982 KL Loss: 7.1389894 DSM Loss: 9.9544722 Overall Loss:18.9104599
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# tensor(17.9502, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.6998910 KL Loss: 7.1512154 DSM Loss: 9.3676726 Overall Loss:18.2187792
# Validation loss decreased (0.581748 --> 0.580876).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(20.9624, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8098895 KL Loss: 7.1372081 DSM Loss: 9.4073291 Overall Loss:18.3544267
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(16.5979, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8203358 KL Loss: 7.2384472 DSM Loss: 9.3005886 Overall Loss:18.3593717
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(18.6128, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7411103 KL Loss: 7.1247075 DSM Loss: 9.5264664 Overall Loss:18.3922838
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.831455409526825
# Use GPU: cuda:0
# >>>>>>>start training : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(41.2795, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8511574 KL Loss: 7.2419942 DSM Loss: 13.8212023 Overall Loss:22.9143540
# Validation loss decreased (inf --> 0.601859).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.2797, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.9056968 KL Loss: 7.2497359 DSM Loss: 10.8666673 Overall Loss:20.0221001
# Validation loss decreased (0.601859 --> 0.580045).  Saving model ...
# Updating learning rate to 0.00025
# tensor(23.5511, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7952538 KL Loss: 7.1359659 DSM Loss: 9.9495472 Overall Loss:18.8807667
# Validation loss decreased (0.580045 --> 0.578329).  Saving model ...
# Updating learning rate to 0.000125
# tensor(16.5037, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7868701 KL Loss: 7.2738126 DSM Loss: 9.3486005 Overall Loss:18.4092833
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(17.1813, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8400640 KL Loss: 7.2528176 DSM Loss: 9.4009139 Overall Loss:18.4937955
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(16.0139, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7557590 KL Loss: 7.1668351 DSM Loss: 9.5343585 Overall Loss:18.4569526
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.8315000534057617
# Use GPU: cuda:0
# >>>>>>>start training : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(29.2165, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8271307 KL Loss: 7.3280358 DSM Loss: 13.7498303 Overall Loss:22.9049966
# Validation loss decreased (inf --> 0.584282).  Saving model ...
# Updating learning rate to 0.0005
# tensor(16.8358, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8371937 KL Loss: 7.2840091 DSM Loss: 10.6519082 Overall Loss:19.7731107
# Validation loss decreased (0.584282 --> 0.582671).  Saving model ...
# Updating learning rate to 0.00025
# tensor(30.3630, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8726765 KL Loss: 7.2546711 DSM Loss: 9.8125071 Overall Loss:18.9398544
# Validation loss decreased (0.582671 --> 0.580922).  Saving model ...
# Updating learning rate to 0.000125
# tensor(19.9799, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7497027 KL Loss: 7.1115488 DSM Loss: 9.5762386 Overall Loss:18.4374900
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(16.0339, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7419285 KL Loss: 7.2330753 DSM Loss: 9.4572956 Overall Loss:18.4322993
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(23.2884, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8685780 KL Loss: 7.3461546 DSM Loss: 8.9864913 Overall Loss:18.2012240
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.8382923007011414
# Use GPU: cuda:0
# >>>>>>>start training : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(24.5617, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8555094 KL Loss: 7.2717182 DSM Loss: 13.9234595 Overall Loss:23.0506869
# Validation loss decreased (inf --> 0.616015).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.8743, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7896384 KL Loss: 7.2724533 DSM Loss: 10.3405117 Overall Loss:19.4026035
# Validation loss decreased (0.616015 --> 0.586315).  Saving model ...
# Updating learning rate to 0.00025
# tensor(16.6359, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7913314 KL Loss: 7.2105522 DSM Loss: 9.9381122 Overall Loss:18.9399958
# Validation loss decreased (0.586315 --> 0.579158).  Saving model ...
# Updating learning rate to 0.000125
# tensor(15.4046, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7594199 KL Loss: 7.1757851 DSM Loss: 9.6984595 Overall Loss:18.6336643
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(16.8679, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8015055 KL Loss: 7.1819797 DSM Loss: 9.4929270 Overall Loss:18.4764120
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(17.3186, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8841746 KL Loss: 7.4016384 DSM Loss: 9.4977355 Overall Loss:18.7835484
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.8300229907035828
# Use GPU: cuda:0
# >>>>>>>start training : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(27.8407, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9109199 KL Loss: 7.3207030 DSM Loss: 12.9765748 Overall Loss:22.2081973
# Validation loss decreased (inf --> 0.601419).  Saving model ...
# Updating learning rate to 0.0005
# tensor(22.5276, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8341892 KL Loss: 7.2113811 DSM Loss: 9.8374536 Overall Loss:18.8830238
# Validation loss decreased (0.601419 --> 0.584713).  Saving model ...
# Updating learning rate to 0.00025
# tensor(14.8166, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8749737 KL Loss: 7.2526294 DSM Loss: 9.5832488 Overall Loss:18.7108519
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(18.0286, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7853832 KL Loss: 7.1387782 DSM Loss: 9.7351420 Overall Loss:18.6593034
# Validation loss decreased (0.584713 --> 0.580379).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(15.5046, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7606374 KL Loss: 7.1013270 DSM Loss: 9.5733670 Overall Loss:18.4353314
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(16.9432, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8085894 KL Loss: 7.2381416 DSM Loss: 9.1281508 Overall Loss:18.1748817
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(15.6698, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7496217 KL Loss: 7.1760598 DSM Loss: 9.3339395 Overall Loss:18.2596211
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : MCD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.8280340433120728
#
#
# Running on file PPL.csv (6/85)...
# Use GPU: cuda:0
# >>>>>>>start training : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(28.4395, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8550696 KL Loss: 7.2959515 DSM Loss: 14.3738388 Overall Loss:23.5248599
# Validation loss decreased (inf --> 0.775236).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.2900, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8020921 KL Loss: 7.1130213 DSM Loss: 10.6382998 Overall Loss:19.5534131
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(18.3543, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8176872 KL Loss: 7.2038657 DSM Loss: 9.9017568 Overall Loss:18.9233098
# Validation loss decreased (0.775236 --> 0.773835).  Saving model ...
# Updating learning rate to 0.000125
# tensor(18.9482, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8631711 KL Loss: 7.2283310 DSM Loss: 10.0310976 Overall Loss:19.1225996
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(15.9122, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7991127 KL Loss: 7.2863403 DSM Loss: 9.9176166 Overall Loss:19.0030697
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(18.6051, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8603754 KL Loss: 7.2925712 DSM Loss: 9.4018639 Overall Loss:18.5548104
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.0951292514801025
# Use GPU: cuda:0
# >>>>>>>start training : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(21.3009, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7697396 KL Loss: 7.2716630 DSM Loss: 15.9420177 Overall Loss:24.9834203
# Validation loss decreased (inf --> 0.787558).  Saving model ...
# Updating learning rate to 0.0005
# tensor(22.5343, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8262854 KL Loss: 7.2127845 DSM Loss: 12.1507453 Overall Loss:21.1898153
# Validation loss decreased (0.787558 --> 0.778762).  Saving model ...
# Updating learning rate to 0.00025
# tensor(21.7656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7875741 KL Loss: 7.2585927 DSM Loss: 10.1361031 Overall Loss:19.1822698
# Validation loss decreased (0.778762 --> 0.774236).  Saving model ...
# Updating learning rate to 0.000125
# tensor(15.9977, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7890888 KL Loss: 7.1911808 DSM Loss: 10.0883052 Overall Loss:19.0685749
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(18.4050, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7188607 KL Loss: 7.1123944 DSM Loss: 9.7726777 Overall Loss:18.6039327
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(18.0136, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7775120 KL Loss: 7.1219074 DSM Loss: 9.7991690 Overall Loss:18.6985883
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.1206586360931396
# Use GPU: cuda:0
# >>>>>>>start training : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(31.1576, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9216425 KL Loss: 7.3438442 DSM Loss: 13.3323785 Overall Loss:22.5978650
# Validation loss decreased (inf --> 0.779104).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.5639, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8461067 KL Loss: 7.1878649 DSM Loss: 10.8441029 Overall Loss:19.8780744
# Validation loss decreased (0.779104 --> 0.777799).  Saving model ...
# Updating learning rate to 0.00025
# tensor(19.3559, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7973833 KL Loss: 7.2434899 DSM Loss: 9.8090648 Overall Loss:18.8499379
# Validation loss decreased (0.777799 --> 0.773865).  Saving model ...
# Updating learning rate to 0.000125
# tensor(18.3904, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7993213 KL Loss: 7.1597764 DSM Loss: 9.6521666 Overall Loss:18.6112642
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(18.4608, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7998029 KL Loss: 7.3018303 DSM Loss: 9.7061201 Overall Loss:18.8077534
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# tensor(16.7728, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7734429 KL Loss: 7.0858471 DSM Loss: 9.5760647 Overall Loss:18.4353548
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.1022247076034546
# Use GPU: cuda:0
# >>>>>>>start training : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.5276, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8471697 KL Loss: 7.2040113 DSM Loss: 12.5557761 Overall Loss:21.6069568
# Validation loss decreased (inf --> 0.796329).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.2663, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.6882299 KL Loss: 7.0930513 DSM Loss: 10.0798424 Overall Loss:18.8611237
# Validation loss decreased (0.796329 --> 0.775184).  Saving model ...
# Updating learning rate to 0.00025
# tensor(20.5456, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8300642 KL Loss: 7.2545128 DSM Loss: 10.0583924 Overall Loss:19.1429697
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(17.5269, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7479418 KL Loss: 7.0981557 DSM Loss: 9.6689834 Overall Loss:18.5150811
# Validation loss decreased (0.775184 --> 0.773043).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(21.4895, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7875763 KL Loss: 7.1767017 DSM Loss: 9.7026035 Overall Loss:18.6668814
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(20.6671, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7820422 KL Loss: 7.1708214 DSM Loss: 9.7684929 Overall Loss:18.7213564
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(16.1377, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7529398 KL Loss: 7.2302505 DSM Loss: 9.7664105 Overall Loss:18.7496008
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.1098458766937256
# Use GPU: cuda:0
# >>>>>>>start training : PPL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.1274, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7919181 KL Loss: 7.2829850 DSM Loss: 13.8531749 Overall Loss:22.9280778
# Validation loss decreased (inf --> 0.785197).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.8364, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8311002 KL Loss: 7.2502214 DSM Loss: 10.7292450 Overall Loss:19.8105666
# ...
# Validation loss decreased (inf --> 0.754208).  Saving model ...
# Updating learning rate to 0.0005
# tensor(20.0093, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7508748 KL Loss: 7.2204561 DSM Loss: 11.2314756 Overall Loss:20.2028064
# Validation loss decreased (0.754208 --> 0.744375).  Saving model ...
# Updating learning rate to 0.00025
# tensor(17.4690, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8641008 KL Loss: 7.1773564 DSM Loss: 10.0471736 Overall Loss:19.0886309
# Validation loss decreased (0.744375 --> 0.743682).  Saving model ...
# Updating learning rate to 0.000125
# tensor(18.8458, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8004893 KL Loss: 7.2590279 DSM Loss: 9.6366316 Overall Loss:18.6961490
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(18.0909, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8023284 KL Loss: 7.1664563 DSM Loss: 9.4458135 Overall Loss:18.4145981
# Validation loss decreased (0.743682 --> 0.741752).  Saving model ...
# Updating learning rate to 3.125e-05
# tensor(17.7401, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7301155 KL Loss: 7.1129633 DSM Loss: 9.5651218 Overall Loss:18.4082007
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-05
# tensor(21.2888, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7391231 KL Loss: 7.2059191 DSM Loss: 9.4462662 Overall Loss:18.3913085
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-06
# tensor(17.1287, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 8, Steps: 31 | MSE Loss: 1.7088735 KL Loss: 7.2382072 DSM Loss: 9.3920570 Overall Loss:18.3391377
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.323111891746521
# Use GPU: cuda:0
# >>>>>>>start training : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(27.2294, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7582271 KL Loss: 7.2277243 DSM Loss: 14.6609884 Overall Loss:23.6469398
# Validation loss decreased (inf --> 0.755917).  Saving model ...
# Updating learning rate to 0.0005
# tensor(23.0524, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8882572 KL Loss: 7.3073931 DSM Loss: 10.5493063 Overall Loss:19.7449565
# Validation loss decreased (0.755917 --> 0.749573).  Saving model ...
# Updating learning rate to 0.00025
# tensor(19.0678, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7431753 KL Loss: 7.1926219 DSM Loss: 10.0395323 Overall Loss:18.9753295
# Validation loss decreased (0.749573 --> 0.743085).  Saving model ...
# Updating learning rate to 0.000125
# tensor(21.9775, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7284562 KL Loss: 7.0510414 DSM Loss: 9.5691136 Overall Loss:18.3486115
# Validation loss decreased (0.743085 --> 0.740561).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(18.9820, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.7150707 KL Loss: 7.1703945 DSM Loss: 9.5143756 Overall Loss:18.3998408
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(17.5352, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7221121 KL Loss: 7.1216872 DSM Loss: 9.4371699 Overall Loss:18.2809692
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(16.9592, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8250202 KL Loss: 7.3384948 DSM Loss: 9.2997508 Overall Loss:18.4632656
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.3259280920028687
# Use GPU: cuda:0
# >>>>>>>start training : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(25.2921, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.7148725 KL Loss: 7.1059769 DSM Loss: 13.7350818 Overall Loss:22.5559313
# Validation loss decreased (inf --> 0.743667).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.9696, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.9074739 KL Loss: 7.2064514 DSM Loss: 10.2452100 Overall Loss:19.3591352
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# tensor(20.0532, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7952093 KL Loss: 7.2279493 DSM Loss: 9.8083616 Overall Loss:18.8315204
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# tensor(17.0683, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7890414 KL Loss: 7.1653640 DSM Loss: 9.3836001 Overall Loss:18.3380055
# Validation loss decreased (0.743667 --> 0.739770).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(19.5096, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8182181 KL Loss: 7.2237176 DSM Loss: 9.4407979 Overall Loss:18.4827336
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(17.7736, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7894361 KL Loss: 7.2466512 DSM Loss: 9.5714290 Overall Loss:18.6075163
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(16.8764, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8618856 KL Loss: 7.1983958 DSM Loss: 9.4114647 Overall Loss:18.4717460
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.3211276531219482
# Use GPU: cuda:0
# >>>>>>>start training : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(31.4885, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9146840 KL Loss: 7.3088610 DSM Loss: 14.1101697 Overall Loss:23.3337146
# Validation loss decreased (inf --> 0.756397).  Saving model ...
# Updating learning rate to 0.0005
# tensor(24.6711, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.7622194 KL Loss: 7.1065182 DSM Loss: 10.3587152 Overall Loss:19.2274529
# Validation loss decreased (0.756397 --> 0.745887).  Saving model ...
# Updating learning rate to 0.00025
# tensor(18.2189, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7539227 KL Loss: 7.1770618 DSM Loss: 9.8648622 Overall Loss:18.7958466
# Validation loss decreased (0.745887 --> 0.740764).  Saving model ...
# Updating learning rate to 0.000125
# tensor(21.3179, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8117193 KL Loss: 7.2244724 DSM Loss: 9.6324318 Overall Loss:18.6686238
# Validation loss decreased (0.740764 --> 0.740577).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(18.8348, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8251771 KL Loss: 7.1671993 DSM Loss: 9.5050417 Overall Loss:18.4974182
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(19.1792, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8099957 KL Loss: 7.2158816 DSM Loss: 9.4092199 Overall Loss:18.4350974
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(18.7937, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8232434 KL Loss: 7.2268462 DSM Loss: 9.3286284 Overall Loss:18.3787177
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : UL.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:1.3173136711120605
#
#
# Running on file GD.csv (12/85)...
# Use GPU: cuda:0
# >>>>>>>start training : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(32.3553, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8666041 KL Loss: 7.3028652 DSM Loss: 14.9446001 Overall Loss:24.1140695
# Validation loss decreased (inf --> 0.993409).  Saving model ...
# Updating learning rate to 0.0005
# tensor(19.5698, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8225176 KL Loss: 7.1032576 DSM Loss: 10.4620421 Overall Loss:19.3878175
# Validation loss decreased (0.993409 --> 0.944793).  Saving model ...
# Updating learning rate to 0.00025
# tensor(18.8860, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7796335 KL Loss: 7.1784590 DSM Loss: 9.9635122 Overall Loss:18.9216046
# Validation loss decreased (0.944793 --> 0.942394).  Saving model ...
# Updating learning rate to 0.000125
# tensor(18.2209, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8057512 KL Loss: 7.2482408 DSM Loss: 9.9280535 Overall Loss:18.9820457
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# tensor(19.3862, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8253107 KL Loss: 7.1853078 DSM Loss: 9.7322306 Overall Loss:18.7428491
# Validation loss decreased (0.942394 --> 0.940744).  Saving model ...
# Updating learning rate to 3.125e-05
# tensor(22.6484, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8008990 KL Loss: 7.2038050 DSM Loss: 9.4884038 Overall Loss:18.4931078
# Validation loss decreased (0.940744 --> 0.935767).  Saving model ...
# Updating learning rate to 1.5625e-05
# tensor(18.4521, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8294925 KL Loss: 7.2429186 DSM Loss: 9.5235815 Overall Loss:18.5959928
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-06
# tensor(18.2227, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 8, Steps: 31 | MSE Loss: 1.7357196 KL Loss: 7.1049399 DSM Loss: 9.4631065 Overall Loss:18.3037659
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-06
# tensor(18.8611, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 9, Steps: 31 | MSE Loss: 1.7174253 KL Loss: 7.2443820 DSM Loss: 9.4012155 Overall Loss:18.3630231
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7822129726409912
# Use GPU: cuda:0
# >>>>>>>start training : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(26.2673, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8923347 KL Loss: 7.2707453 DSM Loss: 13.5152301 Overall Loss:22.6783103
# Validation loss decreased (inf --> 0.968354).  Saving model ...
# Updating learning rate to 0.0005
# Epoch: 2, Steps: 31 | MSE Loss: 1.8580134 KL Loss: 7.2713640 DSM Loss: 10.4440930 Overall Loss:19.5734701
# Validation loss decreased (0.968354 --> 0.939246).  Saving model ...
# Updating learning rate to 0.00025
# tensor(19.3792, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8390162 KL Loss: 7.2144869 DSM Loss: 9.6351203 Overall Loss:18.6886232
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(16.8127, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.7448697 KL Loss: 7.1860097 DSM Loss: 9.8527228 Overall Loss:18.7836020
# Validation loss decreased (0.939246 --> 0.933351).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(19.3253, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8311765 KL Loss: 7.0904379 DSM Loss: 9.6432061 Overall Loss:18.5648205
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(20.0909, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7893023 KL Loss: 7.2007187 DSM Loss: 9.4720899 Overall Loss:18.4621108
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(20.8989, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.7725389 KL Loss: 7.0832774 DSM Loss: 9.3385530 Overall Loss:18.1943691
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7832294702529907
# Use GPU: cuda:0
# >>>>>>>start training : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(25.7757, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.9157716 KL Loss: 7.3652727 DSM Loss: 13.4680744 Overall Loss:22.7491187
# Validation loss decreased (inf --> 1.000700).  Saving model ...
# Updating learning rate to 0.0005
# tensor(23.0633, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8413044 KL Loss: 7.2467388 DSM Loss: 10.5355614 Overall Loss:19.6236043
# Validation loss decreased (1.000700 --> 0.938441).  Saving model ...
# Updating learning rate to 0.00025
# tensor(17.3567, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.7242170 KL Loss: 7.0873489 DSM Loss: 9.9110813 Overall Loss:18.7226472
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(18.0111, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8258340 KL Loss: 7.2683261 DSM Loss: 9.6227714 Overall Loss:18.7169318
# Validation loss decreased (0.938441 --> 0.935599).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(18.6624, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8047645 KL Loss: 7.1879529 DSM Loss: 9.6711497 Overall Loss:18.6638670
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(16.0710, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.7433436 KL Loss: 7.1187602 DSM Loss: 9.5615476 Overall Loss:18.4236514
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(16.8039, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8419352 KL Loss: 7.2594725 DSM Loss: 9.2881065 Overall Loss:18.3895144
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7772865891456604
# Use GPU: cuda:0
# >>>>>>>start training : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(28.8309, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 1, Steps: 31 | MSE Loss: 1.8521512 KL Loss: 7.2397764 DSM Loss: 17.3173494 Overall Loss:26.4092768
# Validation loss decreased (inf --> 0.951044).  Saving model ...
# Updating learning rate to 0.0005
# tensor(23.9970, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 2, Steps: 31 | MSE Loss: 1.8410422 KL Loss: 7.2486895 DSM Loss: 11.4568361 Overall Loss:20.5465679
# Validation loss decreased (0.951044 --> 0.940506).  Saving model ...
# Updating learning rate to 0.00025
# tensor(18.1678, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 3, Steps: 31 | MSE Loss: 1.8742634 KL Loss: 7.2524771 DSM Loss: 10.2975157 Overall Loss:19.4242564
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# tensor(17.3523, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 4, Steps: 31 | MSE Loss: 1.8137522 KL Loss: 7.2704256 DSM Loss: 9.8203082 Overall Loss:18.9044859
# Validation loss decreased (0.940506 --> 0.934384).  Saving model ...
# Updating learning rate to 6.25e-05
# tensor(23.0092, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 5, Steps: 31 | MSE Loss: 1.8148574 KL Loss: 7.1958357 DSM Loss: 9.5834659 Overall Loss:18.5941589
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# tensor(18.5524, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 6, Steps: 31 | MSE Loss: 1.8180148 KL Loss: 7.1040776 DSM Loss: 9.3354771 Overall Loss:18.2575695
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-05
# tensor(17.6485, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch: 7, Steps: 31 | MSE Loss: 1.8601873 KL Loss: 7.2488229 DSM Loss: 9.5093269 Overall Loss:18.6183373
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>start testing : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# test 142
# mse:0.7785603404045105
# Use GPU: cuda:0
# >>>>>>>start training : GD.csv_tp2016_sl10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 510
# val 66
# test 142
# tensor(25.7804, device='cuda:0', grad_fn=<AddBackward0>)
